# %% [markdown]
# # Manipulating Data
#
# Son Huynh
# 31.01.2020

# %% [markdown]
# ## Pandas Documentation:
# - Working with date: https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html
# - Datetime Index: https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DatetimeIndex.html

# %% [markdown]
# ## Table of content:
# * [1. Data Cleaning](#1.-Data-Cleaning)
# * [2. Conditional transformation](#2.-Conditional-Transformation)
# * [3. Time Series transformation](#3.-Time-series-Transformation)
# * [4. Group transformation](#4.-Group-Transformation)

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Data Cleaning

# %% [markdown]
# Guideline on how to approach data cleaning and validating: https://www.kaggle.com/sohier/structured-eda-for-data-cleaning

# %%
aapl = pd.read_csv('AAPL.csv')

aapl.head()
# Out:
#          date    close      volume    open     high       low
# 0       16:00  $202.64  46882304.0  209.43  212.051  201.0000
# 1  2019/08/23  $202.64  46882840.0  209.43  212.051  201.0000
# 2  2019/08/22  $212.46  22267820.0  213.19  214.435  210.7500
# 3  2019/08/21  $212.64  21564750.0  212.99  213.650  211.6032
# 4  2019/08/20  $210.36  26919530.0  210.88  213.350  210.3200

# %%
# The dataset contains some missing values
aapl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1260 entries, 0 to 1259
# Data columns (total 6 columns):
# date      1260 non-null object
# close     1260 non-null object
# volume    1255 non-null float64
# open      1255 non-null float64
# high      1247 non-null float64
# low       1247 non-null float64
# dtypes: float64(4), object(2)
# memory usage: 59.2+ KB

# %% [markdown]
# #### Convert Date column

# %%
# Recommended: use pd.to_datetime() and declare the input format explicitly
aapl.date = pd.to_datetime(aapl.date, format='%Y/%m/%d', errors='coerce')

# %% [markdown]
# The format convention can be seen here:
#
# https://docs.python.org/2/library/datetime.html#strftime-strptime-behavior

# %% [markdown]
# You can use `aapl.date.astype('datetime64')` as well, but `pd.to_datetime()` is faster, more robust and you can specify the format and error handling.

# %% [markdown]
# #### Convert string to number

# %%
aapl.close = aapl.close.str.replace('$', '')

# %%
aapl.close = pd.to_numeric(aapl.close, errors='coerce')

# %% [markdown]
# You can use `.astype(float)` here as well. However, the advantage of `pd.to_numeric()` is that you can specify `errors='coerce'`, which will convert all non-number / missing values (NaN) to `NaN` for you.

# %% [markdown]
# #### Checking missing data

# %%
aapl[aapl.date.isnull()]
# Out:
#   date   close      volume    open     high    low
# 0  NaT  202.64  46882304.0  209.43  212.051  201.0

# %%
aapl[aapl.isnull().any(axis=1)] # select rows with missing data in any column
# Out:
#            date   close      volume     open     high    low
# 0           NaT  202.64  46882304.0  209.430  212.051  201.0
# 51   2019-06-13     NaN         NaN      NaN      NaN    NaN
# 106  2019-03-26  186.79  49696100.0  191.664      NaN    NaN
# 227  2018-09-28  225.74  22560440.0  224.790      NaN    NaN
# 349  2018-04-06     NaN         NaN      NaN      NaN    NaN
# 353  2018-04-02  166.68  37425640.0  167.880      NaN    NaN
# 463  2017-10-20     NaN         NaN      NaN      NaN    NaN
# 480  2017-09-27  154.23  25402270.0  153.800      NaN    NaN
# 581  2017-05-04     NaN         NaN      NaN      NaN    NaN
# 588  2017-04-25  144.53  18325720.0  143.910      NaN    NaN
# 598  2017-04-10     NaN         NaN      NaN      NaN    NaN
# 659  2017-01-11  119.75  27453130.0  118.740      NaN    NaN
# 1037 2015-07-14  125.61  31695870.0  126.040      NaN    NaN
# 1095 2015-04-21  126.91  32341380.0  128.100      NaN    NaN

# %%
aapl[aapl.isnull().all(axis=1)] # only rows with missing data in all columns
# Out:
# Empty DataFrame
# Columns: [date, close, volume, open, high, low]
# Index: []

# %% [markdown]
# #### Remove rows with missing data in one or many columns

# %%
aapl = aapl.dropna(subset=['date'])

# %%
aapl = aapl.dropna(thresh=3) # only keep rows with data in at least 3 columns

# %%
aapl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1254 entries, 1 to 1259
# Data columns (total 6 columns):
# date      1254 non-null datetime64[ns]
# close     1254 non-null float64
# volume    1254 non-null float64
# open      1254 non-null float64
# high      1246 non-null float64
# low       1246 non-null float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 68.6 KB

# %% [markdown]
# #### Fill missing data with some value
#
# There is no best way to fill or drop missing data. Sometimes missing data contain information, thus it is not okay to just drop them. There are multiple approaches to fill and impute missing data. Usually an analyst have to apply logics and knowledge of the data to choose the appropriate method.
#
# https://towardsdatascience.com/missing-values-dont-drop-them-f01b1d8ff557
#
# https://medium.com/ibm-data-science-experience/missing-data-conundrum-exploration-and-imputation-techniques-9f40abe0fd87

# %%
# aapl = aapl.fillna(0) # Fill missing values with zero.

# %%
# Use last available value to fill. Sort_index before this step is necessary.
aapl = aapl.set_index('date').sort_index()
aapl = aapl.fillna(method='ffill')

# You can fill the entire dataframe, or choose one column to apply fillna().

# %%
# The high and low columns on April 21 have been filled with data from April 20

aapl.loc['2015-04-20':'2015-04-22']
# Out:
#              close      volume    open    high     low
# date
# 2015-04-20  127.60  46975110.0  125.57  128.12  125.17
# 2015-04-21  126.91  32341380.0  128.10  128.12  125.17
# 2015-04-22  128.62  37575420.0  126.99  128.87  126.32

# %% [markdown]
# #### Detecting outliers by descriptive statistic and plotting

# %%
aapl.describe() # Some anomaly in max close price
# Out:
#               close        volume         open         high          low
# count   1254.000000  1.254000e+03  1254.000000  1254.000000  1254.000000
# mean     254.049684  3.790008e+07   144.490386   145.785489   143.222344
# std     1256.527286  1.918747e+07    37.200374    37.578899    36.884259
# min       90.340000  1.136205e+07    90.000000    91.670000    89.470000
# 25%      112.105000  2.492191e+07   111.942500   112.800000   110.547500
# 50%      137.050000  3.302024e+07   135.790000   136.465000   135.190000
# 75%      174.727500  4.596147e+07   174.295000   175.287500   173.030000
# max    20386.000000  1.894195e+08   230.780000   233.470000   229.780000

# %%
aapl.close.plot(kind='line') # Some price is too high, must be errors

# %%
aapl[(aapl.close>300)] # These are the rows to be corrected. Looks like they were multiplied by 100 by mistake.
# Out:
#               close      volume    open     high     low
# date
# 2014-09-18  10179.0  36971170.0  101.93  102.350  101.56
# 2014-09-23  10264.0  63255860.0  100.60  102.940  100.54
# 2015-07-13  12566.0  41365600.0  125.03  125.755  124.32
# 2016-09-16  11492.0  79763890.0  115.12  116.130  114.04
# 2016-11-02  11159.0  28174980.0  111.40  112.350  111.23
# 2017-03-27  14088.0  23531670.0  139.39  141.220  138.62
# 2017-04-11  14163.0  30341520.0  142.94  143.350  140.06
# 2018-04-30  16526.0  41976500.0  162.13  167.260  161.84
# 2019-04-18  20386.0  24185530.0  203.12  204.150  202.52
# 2019-05-24  17897.0  23714690.0  180.20  182.140  178.62

# %% [markdown]
# ## 2. Conditional Transformation

# %% [markdown]
# #### np.where() is like for-loop + if-else but vectorized.

# %%
# Let's correct the outliers previously spotted.
aapl.close = np.where((aapl.close > 300), aapl.close/100, aapl.close)

# %% [raw]
# The logic explained:
#
# if aapl.close > 300:
#     aapl.close = aapl.close/100
# else:
#     aapl.close = aapl.close
#
#
# You can add more elif conditions e.g.
#
# np.where(condition1, x1,
#         np.where(condition2, x2,
#             np.where(condition3, x3, ...)))

# %%
aapl.close.plot(kind='line') # Now it looks more correct

# %% [markdown]
# #### Using np.where() to create new column

# %%
aapl['direction'] = np.where((aapl.close > aapl.open), 'up',
                                np.where((aapl.close < aapl.open), 'down', 'unchanged'))

aapl.head()
# Out:
#               close      volume    open    high     low direction
# date
# 2014-08-25  101.540  40087220.0  101.79  102.17  101.28      down
# 2014-08-26  100.889  33079170.0  101.42  101.50  100.86      down
# 2014-08-27  102.130  46807000.0  101.02  102.57  100.70        up
# 2014-08-28  102.250  68368740.0  101.59  102.78  101.56        up
# 2014-08-29  102.500  44516120.0  102.86  102.90  102.20      down

# %% [markdown]
# #### Binning with pd.cut()
#
# Turn continuous data into categories. Useful for things like converting age to age groups.
#
# Check out also pd.qcut()

# %%
bins = [0, 25000000, 50000000, 100000000, 200000000]
labels = ['low', 'medium', 'high', 'very high']

# %%
aapl['volume_cat'] = pd.cut(x=aapl.volume, bins=bins, labels=labels)

aapl
# Out:
#               close      volume    open      high       low direction  \
# date
# 2014-08-25  101.540  40087220.0  101.79  102.1700  101.2800      down
# 2014-08-26  100.889  33079170.0  101.42  101.5000  100.8600      down
# 2014-08-27  102.130  46807000.0  101.02  102.5700  100.7000        up
# 2014-08-28  102.250  68368740.0  101.59  102.7800  101.5600        up
# 2014-08-29  102.500  44516120.0  102.86  102.9000  102.2000      down
# ...             ...         ...     ...       ...       ...       ...
# 2019-08-19  210.350  24431920.0  210.62  212.7307  210.0250      down
# 2019-08-20  210.360  26919530.0  210.88  213.3500  210.3200      down
# 2019-08-21  212.640  21564750.0  212.99  213.6500  211.6032      down
# 2019-08-22  212.460  22267820.0  213.19  214.4350  210.7500      down
# 2019-08-23  202.640  46882840.0  209.43  212.0510  201.0000      down
#
#            volume_cat
# date
# 2014-08-25     medium
# 2014-08-26     medium
# 2014-08-27     medium
# 2014-08-28       high
# 2014-08-29     medium
# ...               ...
# 2019-08-19        low
# 2019-08-20     medium
# 2019-08-21        low
# 2019-08-22        low
# 2019-08-23     medium
#
# [1254 rows x 7 columns]

# %% [markdown]
# ## 3. Time series Transformation

# %% [markdown]
# #### diff()
# Also check out `shift()` and `pct_change()`

# %%
aapl['profit'] = aapl.close.diff(periods=1)

aapl.tail()
# Out:
#              close      volume    open      high       low direction  \
# date
# 2019-08-19  210.35  24431920.0  210.62  212.7307  210.0250      down
# 2019-08-20  210.36  26919530.0  210.88  213.3500  210.3200      down
# 2019-08-21  212.64  21564750.0  212.99  213.6500  211.6032      down
# 2019-08-22  212.46  22267820.0  213.19  214.4350  210.7500      down
# 2019-08-23  202.64  46882840.0  209.43  212.0510  201.0000      down
#
#            volume_cat  profit
# date
# 2019-08-19        low    3.85
# 2019-08-20     medium    0.01
# 2019-08-21        low    2.28
# 2019-08-22        low   -0.18
# 2019-08-23     medium   -9.82

# %% [markdown]
# #### Day of week
#
# Datetime index has some special methods

# %%
aapl['day_of_week'] = aapl.index.day_name()

aapl.head()
# Out:
#               close      volume    open    high     low direction volume_cat  \
# date
# 2014-08-25  101.540  40087220.0  101.79  102.17  101.28      down     medium
# 2014-08-26  100.889  33079170.0  101.42  101.50  100.86      down     medium
# 2014-08-27  102.130  46807000.0  101.02  102.57  100.70        up     medium
# 2014-08-28  102.250  68368740.0  101.59  102.78  101.56        up       high
# 2014-08-29  102.500  44516120.0  102.86  102.90  102.20      down     medium
#
#             profit day_of_week
# date
# 2014-08-25     NaN      Monday
# 2014-08-26  -0.651     Tuesday
# 2014-08-27   1.241   Wednesday
# 2014-08-28   0.120    Thursday
# 2014-08-29   0.250      Friday

# %% [markdown]
# #### Resample
# Resample is just like groupby, but for datetime index.
# You can use resample if you have a datetime index.

# %%
aapl.resample('M').first()
# Out:
#              close      volume    open    high       low direction volume_cat  \
# date
# 2014-08-31  101.54  40087220.0  101.79  102.17  101.2800      down     medium
# 2014-09-30  103.30  53227770.0  103.06  103.74  102.7200        up       high
# 2014-10-31   99.18  51400260.0  100.59  100.69   98.7000      down       high
# 2014-11-30  109.40  52154490.0  108.22  110.30  108.0100        up       high
# 2014-12-31  115.07  83657780.0  118.81  119.25  111.2700      down       high
# ...            ...         ...     ...     ...       ...       ...        ...
# 2019-04-30  191.24  27308200.0  191.64  191.68  188.3800      down     medium
# 2019-05-31  210.52  64827330.0  209.88  215.31  209.2300        up       high
# 2019-06-30  173.30  40396070.0  175.60  177.92  170.2700      down     medium
# 2019-07-31  201.55  27316740.0  203.17  204.49  200.6500      down     medium
# 2019-08-31  208.43  54017920.0  213.90  218.03  206.7435      down       high
#
#             profit day_of_week
# date
# 2014-08-31  -0.651      Monday
# 2014-09-30   0.800     Tuesday
# 2014-10-31  -1.570   Wednesday
# 2014-11-30   1.400      Monday
# 2014-12-31  -3.860      Monday
# ...            ...         ...
# 2019-04-30   1.290      Monday
# 2019-05-31   9.850   Wednesday
# 2019-06-30  -1.770      Monday
# 2019-07-31   3.630      Monday
# 2019-08-31  -4.610    Thursday
#
# [61 rows x 9 columns]

# %%
aapl.resample('Y').mean()
# Out:
#                  close        volume        open        high         low  \
# date
# 2014-12-31  106.504156  5.549187e+07  106.494822  107.542267  105.534858
# 2015-12-31  120.039861  5.164626e+07  120.169524  121.238700  118.854139
# 2016-12-31  104.604008  3.826767e+07  104.507698  105.427063  103.690212
# 2017-12-31  150.574052  2.706258e+07  150.469488  151.418706  149.491396
# 2018-12-31  189.136120  3.376366e+07  189.178076  191.081748  187.267154
# 2019-12-31  187.799259  2.914619e+07  187.511099  189.470063  185.992911
#
#               profit
# date
# 2014-12-31  0.099326
# 2015-12-31 -0.020317
# 2016-12-31  0.041905
# 2017-12-31  0.215363
# 2018-12-31 -0.045960
# 2019-12-31  0.277160

# %% [raw]
# Resample
#
# D - Day
# W - Week
# W-Wed - Week, starting from Wednesday
# M - Month
# Q - Quarter
# Y - Year
#
#
# Return a resampler object, which is similar to a Group by object and has similar methods (sum, mean, count ....)

# %% [markdown]
# ## 4. Structure Transformation

# %% [markdown]
# #### Stack() and unstack()
# Stack/unstack is very useful when you want to transform the structure of your dataframe. Check out `transpose()` also

# %%
stacked = aapl.stack()
stacked # returns a series with 2-levels index
# Out:
# date
# 2014-08-25  close               101.54
#             volume         4.00872e+07
#             open                101.79
#             high                102.17
#             low                 101.28
#                               ...
# 2019-08-23  low                    201
#             direction             down
#             volume_cat          medium
#             profit               -9.82
#             day_of_week         Friday
# Length: 11285, dtype: object

# %%
unstacked = stacked.unstack(level=0) # you can specify which level in the index you want to turn into columns.
unstacked
# Out:
# date          2014-08-25   2014-08-26  2014-08-27   2014-08-28   2014-08-29  \
# close             101.54      100.889      102.13       102.25        102.5
# volume       4.00872e+07  3.30792e+07  4.6807e+07  6.83687e+07  4.45161e+07
# open              101.79       101.42      101.02       101.59       102.86
# high              102.17        101.5      102.57       102.78        102.9
# low               101.28       100.86       100.7       101.56        102.2
# direction           down         down          up           up         down
# volume_cat        medium       medium      medium         high       medium
# profit               NaN       -0.651       1.241         0.12         0.25
# day_of_week       Monday      Tuesday   Wednesday     Thursday       Friday
#
# date          2014-09-02 2014-09-03   2014-09-04 2014-09-05   2014-09-08  ...  \
# close              103.3      98.94        98.12      98.97        98.36  ...
# volume       5.32278e+07   1.25e+08  8.55377e+07  5.828e+07  4.61766e+07  ...
# open              103.06      103.1        98.85       98.8         99.3  ...
# high              103.74      103.2       100.09      99.39        99.31  ...
# low               102.72      98.58        97.79      98.31        98.05  ...
# direction             up       down         down         up         down  ...
# volume_cat          high  very high         high       high       medium  ...
# profit               0.8      -4.36        -0.82       0.85        -0.61  ...
# day_of_week      Tuesday  Wednesday     Thursday     Friday       Monday  ...
#
# date          2019-08-12   2019-08-13   2019-08-14   2019-08-15   2019-08-16  \
# close             200.48       208.97       202.75       201.74        206.5
# volume       2.24819e+07  4.75398e+07  3.65474e+07  2.78834e+07  2.88136e+07
# open              199.62       201.02       203.16       203.46       204.28
# high             202.052       212.14       206.44       205.14       207.16
# low               199.15       200.83      202.587       199.67       203.84
# direction             up           up         down         down           up
# volume_cat           low       medium       medium       medium       medium
# profit             -0.51         8.49        -6.22        -1.01         4.76
# day_of_week       Monday      Tuesday    Wednesday     Thursday       Friday
#
# date          2019-08-19   2019-08-20   2019-08-21   2019-08-22   2019-08-23
# close             210.35       210.36       212.64       212.46       202.64
# volume       2.44319e+07  2.69195e+07  2.15648e+07  2.22678e+07  4.68828e+07
# open              210.62       210.88       212.99       213.19       209.43
# high             212.731       213.35       213.65      214.435      212.051
# low              210.025       210.32      211.603       210.75          201
# direction           down         down         down         down         down
# volume_cat           low       medium          low          low       medium
# profit              3.85         0.01         2.28        -0.18        -9.82
# day_of_week       Monday      Tuesday    Wednesday     Thursday       Friday
#
# [9 rows x 1254 columns]

# %%
aapl.transpose().stack() # Try playing with transpose and stack/unstack to understand them
# Out:
#              date
# close        2014-08-25       101.54
#              2014-08-26      100.889
#              2014-08-27       102.13
#              2014-08-28       102.25
#              2014-08-29        102.5
#                              ...
# day_of_week  2019-08-19       Monday
#              2019-08-20      Tuesday
#              2019-08-21    Wednesday
#              2019-08-22     Thursday
#              2019-08-23       Friday
# Length: 11285, dtype: object

# %% [markdown]
# #### Pivot_table()
# Pivot is great for quick view report on grouped data. It is like a 2 dimension groupby operation. The default groupby function is mean.

# %%
aapl.pivot_table(index='day_of_week', columns='volume_cat', values='close', aggfunc='mean')
# Out:
# volume_cat          low      medium        high   very high
# day_of_week
# Friday       164.132623  143.803493  125.104528  105.760000
# Monday       164.381930  142.113074  127.283214  103.120000
# Thursday     167.447803  140.734081  124.383776         NaN
# Tuesday      162.134062  145.566796  116.641744  111.732500
# Wednesday    165.116119  141.430432  129.615682  109.718889
